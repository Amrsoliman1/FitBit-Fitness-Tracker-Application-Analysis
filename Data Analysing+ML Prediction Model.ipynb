# %% [markdown]
# #**Data Analysing**
#
# ---
#
#
#
# ---

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files


uploaded = files.upload()
# Out:
#      <input type="file" id="files-43362b6f-a94f-4af3-b2dc-5f279a806f7f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-43362b6f-a94f-4af3-b2dc-5f279a806f7f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('DailyActivity.csv')

# %%
df
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    3/25/2016       11004       7.110000         7.110000
# 1    1503960366    3/26/2016       17609      11.550000        11.550000
# 2    1503960366    3/27/2016       12736       8.530000         8.530000
# 3    1503960366    3/28/2016       13231       8.930000         8.930000
# 4    1503960366    3/29/2016       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391     4/8/2016       23014      20.389999        20.389999
# 453  8877689391     4/9/2016       16470       8.070000         8.070000
# 454  8877689391    4/10/2016       28497      27.530001        27.530001
# 455  8877689391    4/11/2016       10622       8.060000         8.060000
# 456  8877689391    4/12/2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
# prompt: I want to know how many id uniqly

df['Id'].nunique()
# Out:
# 35

# %%
df = df[['Id', 'ActivityDate', 'TotalSteps', 'TotalDistance', 'VeryActiveMinutes', 'FairlyActiveMinutes', 'LightlyActiveMinutes', 'SedentaryMinutes', 'Calories']]
df
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  VeryActiveMinutes  \
# 0    1503960366    3/25/2016       11004       7.110000                 33
# 1    1503960366    3/26/2016       17609      11.550000                 89
# 2    1503960366    3/27/2016       12736       8.530000                 56
# 3    1503960366    3/28/2016       13231       8.930000                 39
# 4    1503960366    3/29/2016       12041       7.850000                 28
# ..          ...          ...         ...            ...                ...
# 452  8877689391     4/8/2016       23014      20.389999                 70
# 453  8877689391     4/9/2016       16470       8.070000                 90
# 454  8877689391    4/10/2016       28497      27.530001                128
# 455  8877689391    4/11/2016       10622       8.060000                 18
# 456  8877689391    4/12/2016        2350       1.780000                  0
#
# ...

# %%
# New column called TotalMinutes which combines VeryActiveMinutes	FairlyActiveMinutes	LightlyActiveMinutes	SedentaryMinutes

df['TotalMinutes'] = df['VeryActiveMinutes'] + df['FairlyActiveMinutes'] + df['LightlyActiveMinutes'] + df['SedentaryMinutes']
df
# Out:
# <ipython-input-58-13072fe52b5a>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['TotalMinutes'] = df['VeryActiveMinutes'] + df['FairlyActiveMinutes'] + df['LightlyActiveMinutes'] + df['SedentaryMinutes']
#              Id ActivityDate  TotalSteps  TotalDistance  VeryActiveMinutes  \
# 0    1503960366    3/25/2016       11004       7.110000                 33
# 1    1503960366    3/26/2016       17609      11.550000                 89
# 2    1503960366    3/27/2016       12736       8.530000                 56
# 3    1503960366    3/28/2016       13231       8.930000                 39
# 4    1503960366    3/29/2016       12041       7.850000                 28
# ...

# %%
# make new column for total hours from total minutes and let 2 numbers behind the percentage

df['TotalHours'] = round(df['TotalMinutes'] / 60, 2)
df
# Out:
# <ipython-input-59-895bbb7a3585>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['TotalHours'] = round(df['TotalMinutes'] / 60, 2)
#              Id ActivityDate  TotalSteps  TotalDistance  VeryActiveMinutes  \
# 0    1503960366    3/25/2016       11004       7.110000                 33
# 1    1503960366    3/26/2016       17609      11.550000                 89
# 2    1503960366    3/27/2016       12736       8.530000                 56
# 3    1503960366    3/28/2016       13231       8.930000                 39
# 4    1503960366    3/29/2016       12041       7.850000                 28
# ..          ...          ...         ...            ...                ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 457 entries, 0 to 456
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Id                    457 non-null    int64
#  1   ActivityDate          457 non-null    object
#  2   TotalSteps            457 non-null    int64
#  3   TotalDistance         457 non-null    float64
#  4   VeryActiveMinutes     457 non-null    int64
#  5   FairlyActiveMinutes   457 non-null    int64
#  6   LightlyActiveMinutes  457 non-null    int64
#  7   SedentaryMinutes      457 non-null    int64
#  8   Calories              457 non-null    int64
#  9   TotalMinutes          457 non-null    int64
#  10  TotalHours            457 non-null    float64
# dtypes: float64(2), int64(8), object(1)
# memory usage: 39.4+ KB

# %%
# Convert data type of ActivityDate to Datetime

df['ActivityDate'] = pd.to_datetime(df['ActivityDate'])
# Out:
# <ipython-input-61-ff70ddbaaa4c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ActivityDate'] = pd.to_datetime(df['ActivityDate'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 457 entries, 0 to 456
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Id                    457 non-null    int64
#  1   ActivityDate          457 non-null    datetime64[ns]
#  2   TotalSteps            457 non-null    int64
#  3   TotalDistance         457 non-null    float64
#  4   VeryActiveMinutes     457 non-null    int64
#  5   FairlyActiveMinutes   457 non-null    int64
#  6   LightlyActiveMinutes  457 non-null    int64
#  7   SedentaryMinutes      457 non-null    int64
#  8   Calories              457 non-null    int64
#  9   TotalMinutes          457 non-null    int64
#  10  TotalHours            457 non-null    float64
# dtypes: datetime64[ns](1), float64(2), int64(8)
# memory usage: 39.4 KB

# %%
# I want to get the day name from ActivatyDate in new column called Day

df['Day'] = df['ActivityDate'].dt.day_name()
df
# Out:
# <ipython-input-63-ba8bbaeaf08f>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Day'] = df['ActivityDate'].dt.day_name()
#              Id ActivityDate  TotalSteps  TotalDistance  VeryActiveMinutes  \
# 0    1503960366   2016-03-25       11004       7.110000                 33
# 1    1503960366   2016-03-26       17609      11.550000                 89
# 2    1503960366   2016-03-27       12736       8.530000                 56
# 3    1503960366   2016-03-28       13231       8.930000                 39
# 4    1503960366   2016-03-29       12041       7.850000                 28
# ..          ...          ...         ...            ...                ...
# 452  8877689391   2016-04-08       23014      20.389999                 70
# ...

# %%
df.isnull().sum()
# Out:
# Id                      0
# ActivityDate            0
# TotalSteps              0
# TotalDistance           0
# VeryActiveMinutes       0
# FairlyActiveMinutes     0
# LightlyActiveMinutes    0
# SedentaryMinutes        0
# Calories                0
# TotalMinutes            0
# TotalHours              0
# Day                     0
# dtype: int64

# %%
dub = df.duplicated().sum()
if dub == 0:
    print("There are no duplicated values")
# Out:
# There are no duplicated values

# %%
df.describe()
# Out:
#                  Id    TotalSteps  TotalDistance  VeryActiveMinutes  \
# count  4.570000e+02    457.000000     457.000000         457.000000
# mean   4.628595e+09   6546.562363       4.663523          16.623632
# std    2.293781e+09   5398.493064       4.082072          28.919704
# min    1.503960e+09      0.000000       0.000000           0.000000
# 25%    2.347168e+09   1988.000000       1.410000           0.000000
# 50%    4.057193e+09   5986.000000       4.090000           0.000000
# 75%    6.391747e+09  10198.000000       7.160000          25.000000
# max    8.877689e+09  28497.000000      27.530001         202.000000
#
#        FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  \
# count           457.000000            457.000000        457.000000
# mean             13.070022            170.070022        995.282276
# std              36.208635            122.205372        337.021404
# min               0.000000              0.000000         32.000000
# ...

# %%
df
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  VeryActiveMinutes  \
# 0    1503960366   2016-03-25       11004       7.110000                 33
# 1    1503960366   2016-03-26       17609      11.550000                 89
# 2    1503960366   2016-03-27       12736       8.530000                 56
# 3    1503960366   2016-03-28       13231       8.930000                 39
# 4    1503960366   2016-03-29       12041       7.850000                 28
# ..          ...          ...         ...            ...                ...
# 452  8877689391   2016-04-08       23014      20.389999                 70
# 453  8877689391   2016-04-09       16470       8.070000                 90
# 454  8877689391   2016-04-10       28497      27.530001                128
# 455  8877689391   2016-04-11       10622       8.060000                 18
# 456  8877689391   2016-04-12        2350       1.780000                  0
#
# ...

# %% [markdown]
# #**Data Visualization**
#
# ---
#
#
#
# ---

# %%
df['TotalDistance'].plot(kind='hist', bins=20, title='TotalDistance', color = 'Lightskyblue')
plt.gca().spines[['top', 'right',]].set_visible(False)
plt.xlabel("Total Distance")
# Out:
# Text(0.5, 0, 'Total Distance')

# %%
df.groupby('Day').size().plot(kind='barh', sort_columns=df['Day'], color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right']].set_visible(False)
plt.xlabel('Freq')
plt.title("Distance Frequency")
plt.show()
# Out:
# <ipython-input-69-d977cce8c06c>:1: FutureWarning: `sort_columns` is deprecated and will be removed in a future version.
#   df.groupby('Day').size().plot(kind='barh', sort_columns=df['Day'], color=sns.palettes.mpl_palette('Dark2'))

# %%
df.groupby('Day').size().sort_values(ascending=False).plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right']].set_visible(False)
plt.xlabel('Freq')
plt.title('Days Frequency')
plt.show()

# %%
sns.heatmap(df.corr())
# Out:
# <ipython-input-71-aa4f4450a243>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <Axes: >

# %%
plt.figure(figsize = ((8,6)))
plt.scatter(df.TotalSteps , df.Calories , c = df.Calories)
median_steps = 5986
median_calories = 2062

plt.axhline(median_calories , color = 'black' , label ='Median Of Calories')
plt.axvline(median_steps , color = 'black' , label ='Median Of Steps')

plt.xlabel("Steps")
plt.ylabel("Calories")
plt.title('Calories by Total Steps')
# Out:
# Text(0.5, 1.0, 'Calories by Total Steps')

# %%
plt.figure(figsize = ((8,6)))
plt.scatter(df.TotalSteps , df.Calories , c = df.Calories)
median_steps = 5986
median_calories = 2062

plt.axhline(median_calories , color = 'black' , label ='Median Of Calories')
plt.axvline(median_steps , color = 'black' , label ='Median Of Steps')

plt.xlabel("Steps")
plt.ylabel("Calories")
plt.title('Calories by Total Steps')
# Out:
# Text(0.5, 1.0, 'Calories by Total Steps')

# %%
plt.figure(figsize = ((8,6)))
plt.scatter(df.TotalHours , df.Calories , c = df.Calories)
median_hours = 24
median_calories = 2062

plt.axhline(median_calories , color = 'black' , label ='Median Of Calories')
plt.axvline(median_hours , color = 'black' , label ='Median Of Hours')

plt.xlabel("TotalHours")
plt.ylabel("Calories")
plt.title('Calories by Total Hours')
# Out:
# Text(0.5, 1.0, 'Calories by Total Hours')

# %%
# prompt: I want to know what is the percentage of those three from total time VeryActiveMinutes	FairlyActiveMinutes	LightlyActiveMinutes	SedentaryMinutes in pie chart

labels = ['Very Active Minutes', 'Fairly Active Minutes', 'Lightly Active Minutes', 'Sedentary Minutes']
sizes = [df['VeryActiveMinutes'].mean(), df['FairlyActiveMinutes'].mean(), df['LightlyActiveMinutes'].mean(), df['SedentaryMinutes'].mean()]
colors = sns.palettes.mpl_palette('Set2')

plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%')
plt.title('Ratio of Activity Time')
plt.show()

# %%
# Get the total time for each activity type
total_time = df['TotalMinutes'].sum()

# Calculate the percentage of each activity type
very_active_percentage = df['VeryActiveMinutes'].sum() / total_time * 100
fairly_active_percentage = df['FairlyActiveMinutes'].sum() / total_time * 100
lightly_active_percentage = df['LightlyActiveMinutes'].sum() / total_time * 100
sedentary_percentage = df['SedentaryMinutes'].sum() / total_time * 100

# Create a bar chart
labels = ['Very Active', 'Fairly Active', 'Lightly Active', 'Sedentary']
colors = sns.palettes.mpl_palette('viridis')

plt.bar(labels, [very_active_percentage, fairly_active_percentage, lightly_active_percentage, sedentary_percentage], color=colors)
plt.title('Percentage of Time Spent on Each Activity Type')
plt.xlabel('Activity Type')
plt.ylabel('Percentage (%)')
plt.show()

# %% [markdown]
# #**ML Prediction Model ( XGBoost )**
#
# ---
#
#
#
# ---

# %%
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# Separate features and target
features = df[['TotalSteps', 'TotalDistance', 'TotalHours']]
target = df['Calories']

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# Create a gradient boosting regressor model
model = xgb.XGBRegressor(n_estimators=100, learning_rate=0.1)

# Train the model
model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = model.predict(X_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
print("Mean squared error:", mse)

# Calculate the R^2 score
r2 = model.score(X_test, y_test)
print("R^2 score:", r2)
# Out:
# Mean squared error: 247309.499978578
# R^2 score: 0.6118717481390751

# %%
y_pred
# Out:
# array([2637.3342 , 3154.38   , 1655.1627 , 1655.1627 , 2210.0398 ,
#        2245.4243 , 2182.0835 , 2154.443  , 1655.1627 , 1480.1925 ,
#        2481.3967 , 2554.2705 , 1655.1627 , 2176.5925 , 1985.5808 ,
#        1903.0244 , 2761.392  , 3211.0852 , 2337.4353 , 2475.814  ,
#        2393.619  , 1903.0244 , 2816.4312 , 2000.9868 , 1655.1627 ,
#        1972.8671 , 2787.753  , 2291.244  , 1886.6906 ,  824.32214,
#        2179.1343 , 1851.0347 , 1674.992  , 1888.3721 , 2846.6812 ,
#        2407.281  , 2914.332  , 3372.2803 , 2735.938  , 2624.6768 ,
#        2765.8835 , 1481.6776 , 2836.2722 , 2274.3171 , 2341.143  ,
#        2393.619  , 1559.195  , 2389.998  , 1877.7689 , 2079.397  ,
#        2498.1775 , 1984.8964 , 1655.1627 , 3185.529  , 1591.193  ,
#        2047.4519 , 2065.2463 , 1655.1627 , 2353.44   ,  810.58026,
#        1655.1627 , 1815.7625 , 1845.8922 , 2287.0862 , 2310.4475 ,
#        1657.7847 , 3048.2163 , 3188.4153 , 1448.9769 , 1590.1436 ,
# ...

# %%
X_train
# Out:
#      TotalSteps  TotalDistance  TotalHours
# 17        10990           7.26       18.52
# 66          768           0.53       24.00
# 410        2545           1.68       24.00
# 320        4853           3.66       15.43
# 31         1004           0.65       24.00
# ..          ...            ...         ...
# 106       11230           7.67       24.00
# 270        7998           5.29       24.00
# 348       11761           8.43       16.22
# 435        7238           4.63       15.38
# 102        1846           1.24       24.00
#
# [365 rows x 3 columns]

# %%
X_test
# Out:
#      TotalSteps  TotalDistance  TotalHours
# 304       14873          11.11       17.57
# 39        20237          14.71       24.00
# 341           0           0.00       24.00
# 218           0           0.00       24.00
# 155       11508           7.70       18.02
# ..          ...            ...         ...
# 137           0           0.00       24.00
# 93         5142           3.19       14.73
# 57         6556           4.34       18.58
# 154        7618           5.10       19.17
# 24         1675           1.09       24.00
#
# [92 rows x 3 columns]

# %% [markdown]
#  **Save The Model**

# %%
# save this model

import pickle

# Save the model to a file
with open('model.pkl', 'wb') as f:
  pickle.dump(model, f)

# Load the model from the file
with open('model.pkl', 'rb') as f:
  loaded_model = pickle.load(f)

# %%
# Import necessary libraries
import pickle
import numpy as np

# Load the model from the file
with open('model.pkl', 'rb') as f:
    loaded_model = pickle.load(f)

# Create the features array
features = np.array([[1.5, 50, 12]])

# Make a prediction using the loaded model
prediction = loaded_model.predict(features)[0]

# Print the prediction
print(f"Predicted Calories: {prediction:.2f}")
# Out:
# Predicted Calories: 3281.13

# %% [markdown]
# # **Graphical User Interface (GUI)**

# %%
# Import necessary libraries
import pickle
import numpy as np
from ipywidgets import ToggleButtons, FloatSlider, Button, VBox, HBox, Label, Text, Output

# Load the model from the file
with open('model.pkl', 'rb') as f:
    loaded_model = pickle.load(f)

# Create the widgets
model_selector = ToggleButtons(
    description='Model:',
    options=['XGBoost'],
    value='XGBoost'
)

step_slider = FloatSlider(
    description='Step Size:',
    min=0.1,
    max=10,
    value=1,
    step=0.1
)

distance_slider = FloatSlider(
    description='Distance:',
    min=0,
    max=100,
    value=50,
    step=1
)

hours_slider = FloatSlider(
    description='Hours:',
    min=0,
    max=24,
    value=12,
    step=1
)

predict_button = Button(
    description='Predict'
)

output_label = Label()

# Define the predict function
def predict(model, step, distance, hours):
    # Create the features array
    features = np.array([[step, distance, hours]])

    # Predict using the selected model
    if model == 'XGBoost':
        prediction = loaded_model.predict(features)[0]
    else:
        # Placeholder for predictions using other models (not provided in this example)
        prediction = 0

    # Display the prediction
    output_label.value = f'Predicted Calories: {prediction:.2f}'

# Connect the button click event to the predict function
predict_button.on_click(lambda b: predict(model_selector.value, step_slider.value, distance_slider.value, hours_slider.value))

# Create the layout
ui = VBox([
    HBox([model_selector, step_slider]),
    HBox([distance_slider, hours_slider]),
    predict_button,
    output_label
])

# Display the UI
ui

# %% [markdown]
# # **Decision recommendation after analysing Data**
# 1. **Increase daily step count:** Aim for at least 7,000 steps per day to improve overall health and fitness.
#
#
# 2. **Balance activity types:** Ensure a healthy balance between different activity types. Aim for at least 30 minutes of moderate-intensity exercise most days of the week, including activities like brisk walking, cycling, or swimming.
#
#
# 3. **Prioritize sleep:** Sufficient sleep is crucial for physical and mental well-being. Aim for 7-8 hours of quality sleep each night.
#
#
# 4. **Monitor calorie intake:** Keep track of calorie intake to maintain a healthy weight. Consider using a food diary or calorie-tracking app to monitor your daily intake.
#
#
# 5. **Stay hydrated:** Drink plenty of water throughout the day to stay hydrated and support overall health.
#
#
# 6. **Reduce sedentary time:** Minimize prolonged periods of sitting or inactivity. Take regular breaks to move around, stand up, or stretch.
#
#
# 7. **Set realistic goals:** Gradually increase your activity levels and set achievable goals for yourself. Don't try to make drastic changes all at once, as this can lead to burnout.
#
#
# 8. **Find enjoyable activities:** Choose activities that you enjoy and find motivating. This will make it easier to stick with your fitness routine in the long run.
#
#
# 9. **Seek support:** Consider joining a fitness group or finding a workout buddy to provide motivation and support.
#
#
#
# 10. **Monitor progress:** Regularly track your progress and celebrate your achievements. This can help boost your motivation and keep you on track.
